# %%
#Creating Events and Subscribers Datababses

from pymongo import MongoClient

# Connection string with the actual MongoDB username and password
connection_string = "mongodb+srv://nofilsiddiqui:assignment02@assignment02.cwczo.mongodb.net/?retryWrites=true&w=majority&appName=Assignment02"
client = MongoClient(connection_string)

# Access the Assignment-02 database
db = client['Assignment-02']

# Collections
events_collection = db['events']
subscribers_collection = db['subscribers']

# Function to subscribe a subscriber to an event
def subscribe_to_event(subscriber_id, event_id):
    events_collection.update_one(
        {"event_id": event_id},
        {"$push": {"subscribers": subscriber_id}}
    )
    subscribers_collection.update_one(
        {"subscriber_id": subscriber_id},
        {"$push": {"subscribed_events": event_id}}
    )
    print(f"Subscriber {subscriber_id} subscribed to Event {event_id}")

# Function to publish an event to all subscribers
def publish_event(event_id):
    event = events_collection.find_one({"event_id": event_id})
    if event:
        subscribers = event['subscribers']
        for subscriber_id in subscribers:
            subscriber = subscribers_collection.find_one({"subscriber_id": subscriber_id})
            if subscriber:
                print(f"Notifying {subscriber['name']} ({subscriber['email']}) about {event['title']}")
    else:
        print(f"Event with ID {event_id} not found.")

# Insert sample data into the events and subscribers collections
def insert_sample_data():
    # Insert sample events
    events = [
        {"event_id": "E001", "title": "Open House", "description": "Introduction to our programs", "date": "2024-09-01", "subscribers": []},
        {"event_id": "E002", "title": "Workshop", "description": "Hands-on workshop", "date": "2024-09-15", "subscribers": []},
        # Add more events as needed
    ]
    try:
        events_collection.insert_many(events)
        print("Sample events inserted.")
    except Exception as e:
        print(f"Error inserting events: {e}")

    # Insert sample subscribers
    subscribers = [
        {"subscriber_id": "S001", "name": "John Doe", "email": "john.doe@example.com", "subscribed_events": []},
        {"subscriber_id": "S002", "name": "Jane Smith", "email": "jane.smith@example.com", "subscribed_events": []},
        # Add more subscribers as needed
    ]
    try:
        subscribers_collection.insert_many(subscribers)
        print("Sample subscribers inserted.")
    except Exception as e:
        print(f"Error inserting subscribers: {e}")

# Example usage
try:
    insert_sample_data()  # Insert the sample data
    subscribe_to_event("S001", "E001")  # Subscribe John Doe to the Open House event
    publish_event("E001")  # Publish the Open House event
except Exception as e:
    print(f"An error occurred: {e}")

# Close the connection
client.close()
# Out:
# Sample events inserted.
# Sample subscribers inserted.
# Subscriber S001 subscribed to Event E001
# Notifying John Doe (john.doe@example.com) about Open House

# %%
from pymongo import MongoClient

# Establish the connection
client = MongoClient("mongodb+srv://nofilsiddiqui:assignment02@assignment02.cwczo.mongodb.net/?retryWrites=true&w=majority&appName=Assignment02")

# Access the Assignment-02 database
db = client['Assignment-02']

# Collections
events_collection = db['events']
subscribers_collection = db['subscribers']

# Step 1: Clear Existing Data
def clear_collections():
    events_collection.delete_many({})
    subscribers_collection.delete_many({})
    print("Cleared existing data in events and subscribers collections.")

# Step 2: Insert Sample Data
def insert_sample_data():
    # Manually create 20 sample events
    events = [
        {"event_id": "E001", "title": "Orientation Day", "description": "University orientation for new students", "date": "2024-09-01", "subscribers": []},
        {"event_id": "E002", "title": "Tech Talk", "description": "Discussion on the latest tech trends", "date": "2024-09-05", "subscribers": []},
        {"event_id": "E003", "title": "Career Fair", "description": "Meet potential employers", "date": "2024-09-10", "subscribers": []},
        {"event_id": "E004", "title": "Workshop on AI", "description": "Learn about AI tools", "date": "2024-09-15", "subscribers": []},
        {"event_id": "E005", "title": "Alumni Meet", "description": "Reunite with fellow alumni", "date": "2024-09-20", "subscribers": []},
        {"event_id": "E006", "title": "Cultural Fest", "description": "Showcase of cultural performances", "date": "2024-09-25", "subscribers": []},
        {"event_id": "E007", "title": "Open House", "description": "Tour of the university campus", "date": "2024-09-30", "subscribers": []},
        {"event_id": "E008", "title": "Sports Day", "description": "University-wide sports events", "date": "2024-10-05", "subscribers": []},
        {"event_id": "E009", "title": "Music Concert", "description": "Live music performance by students", "date": "2024-10-10", "subscribers": []},
        {"event_id": "E010", "title": "Art Exhibition", "description": "Exhibition of art by students", "date": "2024-10-15", "subscribers": []},
        {"event_id": "E011", "title": "Tech Expo", "description": "Exhibition of tech projects", "date": "2024-10-20", "subscribers": []},
        {"event_id": "E012", "title": "Volunteer Fair", "description": "Find volunteer opportunities", "date": "2024-10-25", "subscribers": []},
        {"event_id": "E013", "title": "Debate Competition", "description": "University-wide debate competition", "date": "2024-11-01", "subscribers": []},
        {"event_id": "E014", "title": "Science Fair", "description": "Showcase of scientific projects", "date": "2024-11-05", "subscribers": []},
        {"event_id": "E015", "title": "Coding Bootcamp", "description": "Intensive coding session", "date": "2024-11-10", "subscribers": []},
        {"event_id": "E016", "title": "Entrepreneurship Summit", "description": "Meet aspiring entrepreneurs", "date": "2024-11-15", "subscribers": []},
        {"event_id": "E017", "title": "Guest Lecture", "description": "Lecture by an industry expert", "date": "2024-11-20", "subscribers": []},
        {"event_id": "E018", "title": "Hackathon", "description": "24-hour coding competition", "date": "2024-11-25", "subscribers": []},
        {"event_id": "E019", "title": "Dance Competition", "description": "University-wide dance competition", "date": "2024-12-01", "subscribers": []},
        {"event_id": "E020", "title": "End-of-Year Party", "description": "Celebration to end the year", "date": "2024-12-10", "subscribers": []}
    ]

    # Insert the sample events into the events collection
    events_collection.insert_many(events)
    print("Inserted 20 sample events.")

    # Manually create 20 sample subscribers
    subscribers = [
        {"subscriber_id": "S001", "name": "Nofil Siddiqui", "email": "nofilsiddiqui2000@gmail.com", "subscribed_events": []},
        {"subscriber_id": "S002", "name": "Adnan Khan", "email": "khanadnan64@gmail.com", "subscribed_events": []},
        {"subscriber_id": "S003", "name": "Wasea", "email": "wasea@gmail.com", "subscribed_events": []},
        {"subscriber_id": "S004", "name": "Afnan Khan", "email": "afnankhan@gmail.com", "subscribed_events": []},
        {"subscriber_id": "S005", "name": "Adeela Junejo", "email": "adeela@gmail.com", "subscribed_events": []},
        {"subscriber_id": "S006", "name": "Mehek", "email": "Mehek@example.com", "subscribed_events": []},
        {"subscriber_id": "S007", "name": "Damisha", "email": "Damisha@example.com", "subscribed_events": []},
        {"subscriber_id": "S008", "name": "Zahra", "email": "Zahra@example.com", "subscribed_events": []},
        {"subscriber_id": "S009", "name": "Almas", "email": "Almas@example.com", "subscribed_events": []},
        {"subscriber_id": "S010", "name": "Ayesha", "email": "Ayesha@example.com", "subscribed_events": []},
        {"subscriber_id": "S011", "name": "Noor", "email": "Noor@example.com", "subscribed_events": []},
        {"subscriber_id": "S012", "name": "Lalarukh", "email": "Lalarukh@example.com", "subscribed_events": []},
        {"subscriber_id": "S013", "name": "Hehehe", "email": "Hehehe@example.com", "subscribed_events": []},
        {"subscriber_id": "S014", "name": "Kashif Siddiqui", "email": "Kashif@example.com", "subscribed_events": []},
        {"subscriber_id": "S015", "name": "Olivia King", "email": "olivia.king@example.com", "subscribed_events": []},
        {"subscriber_id": "S016", "name": "Paul Wright", "email": "paul.wright@example.com", "subscribed_events": []},
        {"subscriber_id": "S017", "name": "Quincy Scott", "email": "quincy.scott@example.com", "subscribed_events": []},
        {"subscriber_id": "S018", "name": "Rachel Green", "email": "rachel.green@example.com", "subscribed_events": []},
        {"subscriber_id": "S019", "name": "Steve Adams", "email": "steve.adams@example.com", "subscribed_events": []},
        {"subscriber_id": "S020", "name": "Tina Turner", "email": "tina.turner@example.com", "subscribed_events": []}
    ]

    # Insert the sample subscribers into the subscribers collection
    subscribers_collection.insert_many(subscribers)
    print("Inserted 20 sample subscribers.")

# Step 3: Execute the functions
clear_collections()
insert_sample_data()

# Close the connection
client.close()
# Out:
# Cleared existing data in events and subscribers collections.
# Inserted 20 sample events.
# Inserted 20 sample subscribers.
